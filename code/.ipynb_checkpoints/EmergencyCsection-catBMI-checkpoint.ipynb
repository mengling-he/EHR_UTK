# %%
import pandas as pd
import numpy as np
import scipy.stats as st
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.inspection import permutation_importance

import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df_complete = pd.read_csv('../data/data_complete.csv')
df_mean = pd.read_csv('../data/data_mean.csv', index_col=0)
df_ml = pd.read_csv('../data/data_ml.csv', index_col=0)
#df_mice = pd.read_csv('../data/data_mice.csv', index_col=0)

# %%
df_complete
# Out:
#         Age  Gravida  Para Episiotomy Laceration.Extension  \
# County
# knox     25        3     2       None               Second
# knox     33        6     5       None               NAnone
# knox     34        1     0       None               NAnone
# loudon   28        3     1       None               NAnone
# blount   31        2     1       None               Second
# ...     ...      ...   ...        ...                  ...
# cocke    21        2     1       None               NAnone
# knox     21        2     0       None               NAnone
# knox     34        4     1       None                First
# knox     34        4     3       None               NAnone
# sevier   23        2     1       None               NAnone
#
#        Amniotic.Fluid.Color Attempt.to.Vbac Csection.Incidence  \
# County
# knox                  clear              No             NAnone
# knox                 bloody          NAnone             NAnone
# knox         heavy meconium          NAnone            Primary
# loudon    moderate meconium          NAnone             NAnone
# blount                clear          NAnone             NAnone
# ...                     ...             ...                ...
# cocke                 clear          NAnone             NAnone
# knox                 bloody              No             NAnone
# knox                  clear          NAnone             NAnone
# knox                  clear          NAnone             NAnone
# sevier                clear          NAnone             NAnone
#
#        Csection.Urgency Membranes.Rupture.Method  ...  \
# County                                            ...
# knox             NAnone                     SROM  ...
# knox             NAnone                     AROM  ...
# knox            Nonemer                     AROM  ...
# loudon           NAnone                     SROM  ...
# blount           NAnone                     AROM  ...
# ...                 ...                      ...  ...
# cocke            NAnone                     AROM  ...
# knox             NAnone                     AROM  ...
# knox             NAnone                     SROM  ...
# knox             NAnone                     AROM  ...
# sevier           NAnone                     AROM  ...
#
#         reason_for_admission_ROM reason_for_admission_Observe  \
# County
# knox                       False                        False
# knox                       False                         True
# knox                       False                        False
# loudon                     False                        False
# blount                      True                         True
# ...                          ...                          ...
# cocke                      False                        False
# knox                       False                        False
# knox                        True                        False
# knox                       False                        False
# sevier                     False                        False
#
#        reason_for_admission_other  race_black race_white  \
# County
# knox                        False       False      False
# knox                        False        True      False
# knox                        False       False       True
# loudon                      False       False       True
# blount                       True       False       True
# ...                           ...         ...        ...
# cocke                       False       False       True
# knox                        False        True      False
# knox                        False       False       True
# knox                        False       False       True
# sevier                      False       False       True
#
#        race_pacific_islander  race_asian  race_arabic race_american_indian  \
# County
# knox                   False       False        False                False
# knox                   False       False        False                False
# knox                   False       False        False                False
# loudon                 False       False        False                False
# blount                 False       False        False                False
# ...                      ...         ...          ...                  ...
# cocke                  False       False        False                False
# knox                   False       False        False                False
# knox                   False       False        False                False
# knox                   False       False        False                False
# sevier                 False       False        False                False
#
#        race_other
# County
# knox         True
# knox        False
# knox        False
# loudon      False
# blount      False
# ...           ...
# cocke       False
# knox        False
# knox        False
# knox        False
# sevier      False
#
# [3140 rows x 92 columns]

# %%
sum(df_ml.isna().any())
# Out:
# 0

# %%
df_complete.shape
# Out:
# (3140, 92)

# %%
df_mean.shape
# Out:
# (17620, 93)

# %%
df_ml.shape
# Out:
# (17620, 93)

# %%
# delete the scheduled samples
df_complete = df_complete[df_complete['Csection.Urgency'] != 'Schedule']
df_mean = df_mean[df_mean['Csection.Urgency'] != 'Schedule']
df_ml = df_ml[df_ml['Csection.Urgency'] != 'Schedule']
#df_mice = df_mice[df_mice['Csection.Urgency'] != 'Schedule']

# %%
print(df_complete['Csection.Urgency'].value_counts())
print(df_mean['Csection.Urgency'].value_counts())
print(df_ml['Csection.Urgency'].value_counts())
#print(df_mice['Csection.Urgency'].value_counts())
# Out:
# NAnone      3050
# Nonemer       83
# Emergent       5
# Name: Csection.Urgency, dtype: int64
# NAnone      12334
# Nonemer      2572
# Emergent      500
# Name: Csection.Urgency, dtype: int64
# NAnone      12334
# Nonemer      2572
# Emergent      500
# Name: Csection.Urgency, dtype: int64

# %%
# delete Method.of.Delivery.A for predicting Csection.Urgency
del df_complete['Method.of.Delivery.A']
del df_mean['Method.of.Delivery.A']
del df_ml['Method.of.Delivery.A']
#del df_mice['Method.of.Delivery.A']

# %%
# delete Method.of.Delivery.A for predicting Csection.Urgency
del df_complete['Csection.Incidence']
del df_mean['Csection.Incidence']
del df_ml['Csection.Incidence']
#del df_mice['Csection.Incidence']

# %%
urgency_complete = df_complete.pop('Csection.Urgency')
urgency_mean = df_mean.pop('Csection.Urgency')
urgency_ml = df_ml.pop('Csection.Urgency')
#urgency_mice = df_mice.pop('Csection.Urgency')

# %%
labels_complete=LabelEncoder().fit_transform(urgency_complete)
labels_mean=LabelEncoder().fit_transform(urgency_mean)
labels_ml=LabelEncoder().fit_transform(urgency_ml)
#labels_mice=pd.get_dummies(urgency_mice)['NAnone'].astype('category')

# %%
urgency_complete.value_counts()
# Out:
# NAnone      3050
# Nonemer       83
# Emergent       5
# Name: Csection.Urgency, dtype: int64

# %%
print(Counter(labels_complete))
# Out:
# Counter({1: 3050, 2: 83, 0: 5})

# %% [markdown]
# ###  Model (use. LR to see which dataset has the best performance)

# %%
from functions import helpers
from functions import models
from functions import classifiers

# %%
features_complete = pd.get_dummies(df_complete)
features_mean = pd.get_dummies(df_mean)
features_ml = pd.get_dummies(df_ml)
#features_mice = pd.get_dummies(df_mice)

# %% [markdown]
# ### data : complete

# %%
X1_train, X1_test, y1_train, y1_test = helpers.split_and_scale_data(features_complete, labels_complete)

# %%
print(Counter(y1_train))
# Out:
# Counter({1: 2138, 2: 55, 0: 3})

# %%
print(Counter(y1_test))
# Out:
# Counter({1: 912, 2: 28, 0: 2})

# %%
X1_train.shape
# Out:
# (2196, 196)

# %%
X1_test.shape
# Out:
# (942, 196)

# %%
X1_train, y1_train = helpers.perform_SMOTE(X1_train, y1_train,k_neighbors=2)
print(Counter(y1_train))
# Out:
# Counter({1: 2138, 2: 2138, 0: 2138})

# %%
def run_Multinomial1(X_train_scaled, X_test_scaled, y_train, y_test):###872510-1992
    model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
    model.fit(X_train_scaled, y_train)
    # define the model evaluation procedure
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    # evaluate the model and collect the scores
    n_scores = cross_val_score(model, X_train_scaled, y_train, scoring='accuracy', cv=cv, n_jobs=-1)
    # report the model performance
    print('Mean Accuracy: %.3f (%.3f)' % (np.mean(n_scores), np.std(n_scores)))
    
    yhat = model.predict_proba(X_test_scaled)
    y_pred = model.predict(X_test_scaled)
    # Generate confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix:")
    print(cm)
    # Generate detailed classification report
    report = classification_report(y_test, y_pred,output_dict=True)
    print("\nClassification Report:")
    print(report)
    
    
    # Calculate permutation importance
    result = permutation_importance(model, X_test_scaled, y_test, n_repeats=10, random_state=42, n_jobs=-1)
    importances = result.importances_mean
    abs_importances = np.abs(importances)
    indices = np.argsort(abs_importances)[::-1][:20]
    top_20_features = [X_test_scaled.columns[i] for i in indices]
    top_20_importances = importances[indices]
    # Plot the top 20 features and their importance
    plt.figure(figsize=(10, 6))
    plt.barh(top_20_features, top_20_importances, color='skyblue')
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.title('Top 20 Feature Importances')
    plt.gca().invert_yaxis()  # Invert y-axis to have the highest importance at the top
    plt.show()
   

    return model,report, importances,top_20_features

# %%
model1,importance1,features_i1,top_features_complete = run_Multinomial1(X1_train, X1_test, y1_train, y1_test)
# Out:
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Mean Accuracy: 0.998 (0.002)
# Confusion Matrix:
# [[  0   0   2]
#  [  0 908   4]
#  [  0   4  24]]
#
# Classification Report:
# {'0': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2}, '1': {'precision': 0.9956140350877193, 'recall': 0.9956140350877193, 'f1-score': 0.9956140350877193, 'support': 912}, '2': {'precision': 0.8, 'recall': 0.8571428571428571, 'f1-score': 0.8275862068965518, 'support': 28}, 'accuracy': 0.9893842887473461, 'macro avg': {'precision': 0.5985380116959065, 'recall': 0.6175856307435255, 'f1-score': 0.6077334139947571, 'support': 942}, 'weighted avg': {'precision': 0.9876857749469214, 'recall': 0.9893842887473461, 'f1-score': 0.9885057471264368, 'support': 942}}
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### data : mean

# %%
X2_train, X2_test, y2_train, y2_test = helpers.split_and_scale_data(features_mean, labels_mean)

# %%
print(Counter(y2_train))
# Out:
# Counter({1: 8608, 2: 1815, 0: 361})

# %%
print(Counter(y2_test))
# Out:
# Counter({1: 3726, 2: 757, 0: 139})

# %%
X2_train, y2_train = helpers.perform_SMOTE(X2_train, y2_train)
print(Counter(y2_train))
# Out:
# Counter({1: 8608, 2: 8608, 0: 8608})

# %%
model2,importance2,features_i2,top_features_mean = run_Multinomial1(X2_train, X2_test, y2_train, y2_test)
# Out:
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Mean Accuracy: 0.898 (0.008)
# Confusion Matrix:
# [[  89    9   41]
#  [  52 3577   97]
#  [ 154   36  567]]
#
# Classification Report:
# {'0': {'precision': 0.3016949152542373, 'recall': 0.6402877697841727, 'f1-score': 0.4101382488479263, 'support': 139}, '1': {'precision': 0.9875759249033683, 'recall': 0.9600107353730543, 'f1-score': 0.9735982580293957, 'support': 3726}, '2': {'precision': 0.8042553191489362, 'recall': 0.7490092470277411, 'f1-score': 0.7756497948016415, 'support': 757}, 'accuracy': 0.915837299870186, 'macro avg': {'precision': 0.6978420531021806, 'recall': 0.783102584061656, 'f1-score': 0.7197954338929878, 'support': 4622}, 'weighted avg': {'precision': 0.9369244409359657, 'recall': 0.915837299870186, 'f1-score': 0.9242326310411582, 'support': 4622}}

# %% [markdown]
# ### data:ml

# %%
X_train, X_test, y_train, y_test = helpers.split_and_scale_data(features_ml, labels_ml)

# %%
print(Counter(y_train))
print(Counter(y_test))
# Out:
# Counter({1: 8608, 2: 1815, 0: 361})
# Counter({1: 3726, 2: 757, 0: 139})

# %%
X_train, y_train = helpers.perform_SMOTE(X_train, y_train)
print(Counter(y_train))
# Out:
# Counter({1: 8608, 2: 8608, 0: 8608})

# %%
model3,importance3,features_i3,top_features_ml = run_Multinomial1(X_train, X_test, y_train, y_test)
# Out:
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Mean Accuracy: 0.899 (0.007)
# Confusion Matrix:
# [[  90    9   40]
#  [  50 3577   99]
#  [ 149   38  570]]
#
# Classification Report:
# {'0': {'precision': 0.31141868512110726, 'recall': 0.6474820143884892, 'f1-score': 0.4205607476635514, 'support': 139}, '1': {'precision': 0.9870309050772627, 'recall': 0.9600107353730543, 'f1-score': 0.9733333333333334, 'support': 3726}, '2': {'precision': 0.8039492242595204, 'recall': 0.7529722589167768, 'f1-score': 0.7776261937244201, 'support': 757}, 'accuracy': 0.9167027260926006, 'macro avg': {'precision': 0.7007996048192968, 'recall': 0.7868216695594401, 'f1-score': 0.7238400915737683, 'support': 4622}, 'weighted avg': {'precision': 0.9367273717685356, 'recall': 0.9167027260926006, 'f1-score': 0.9246562034994852, 'support': 4622}}

# %% [markdown]
# The permutation importance for a multinomial logistic regression model provides an indication of how much each feature contributes to the model's predictive power. By permuting each feature and observing the change in performance, you can determine the importance of each feature. This method is model-agnostic and can be applied to any classifier.

# %%
coefficients3 = model3.coef_

# Get the intercepts
intercepts3 = model3.intercept_

# %%
# Print the coefficients with feature names
print("Coefficients:")

for i, class_coefficients in enumerate(coefficients3):
    feature_list = []
    print(f"\nClass {model3.classes_[i]} coefficients:")
    for feature, coef in zip(X_train.columns, class_coefficients):
        print(f"{feature}: {coef:.4f}")
        feature_list.append(feature)

print("\nIntercepts:")
for i, intercept in enumerate(intercepts3):
    print(f"Class {model3.classes_[i]} intercept: {intercept:.4f}")
# Out:
# Coefficients:
#
# Class 0 coefficients:
# Age: 0.3094
# Gravida: -0.4229
# Para: -0.1146
# Number.of.Babies.In.Womb: 0.0477
# Delivery.Year: -0.0132
# Infant.Cord.Vessels.A: -0.1558
# Infant.Length.A: -0.0303
# Birthweight.A: -0.2843
# GA.At.Birth.A: 0.3130
# Weight.Prepregnancy: -0.5543
# Weight.Gain.Pounds: -0.0862
# OFC.At.Birth.Baby.A.In: -0.0510
# Quantitative.Blood.Loss.DS: 0.3623
# Weight.Delivery: 0.6354
# BMI_delivery: -0.0690
# BMI_prepregnancy: 0.2154
# Labortime: 0.1383
# delivery_anesthesia_epidural: 0.2834
# delivery_anesthesia_spinal: 0.6569
# delivery_anesthesia_local: -0.8908
# delivery_anesthesia_pudenal: -0.1390
# delivery_anesthesia_cse: 0.0887
# delivery_anesthesia_general: 1.3407
# delivery_anesthesia_intrathe: -0.1550
# labor_anesthesia_epidural: -0.1757
# labor_anesthesia_spinal: -0.5527
# labor_anesthesia_cse: -0.2657
# labor_anesthesia_general: 0.6276
# labor_anesthesia_iv_sedation: 0.1622
# laceration_type_none: 0.5371
# laceration_type_vaginal: 0.5606
# laceration_type_perineal: 1.0755
# laceration_type_periuret: -0.3833
# laceration_type_cervical: -0.0782
# laceration_type_other: -1.3046
# infant_complications_A_brady: 0.6630
# infant_complications_A_acidosis: -0.2588
# infant_complications_A_meconium: -0.0086
# infant_complications_A_cord_pro: 0.7502
# infant_complications_A_MLD: 0.5344
# infant_complications_A_MVD: 0.2274
# infant_complications_A_oligohyd: -0.3676
# infant_complications_A_shol_dys: -1.5524
# infant_complications_A_polyhydr: -0.1338
# infant_complications_A_decvarib: -0.0291
# infant_complications_A_tachy: 0.1667
# infant_complications_A_other: 0.4162
# reason_for_admission_Spon_Ab: -0.8699
# reason_for_admission_Labor: 0.1295
# reason_for_admission_PTL: -0.0897
# reason_for_admission_Induce: 0.4244
# reason_for_admission_Rept_CS: 0.1976
# reason_for_admission_Prim_CS: 0.3194
# reason_for_admission_ROM: 0.1073
# reason_for_admission_Observe: 0.1720
# reason_for_admission_other: 0.2860
# race_black: 0.1685
# race_white: 0.0548
# race_pacific_islander: -0.0607
# race_asian: -0.1181
# race_arabic: 0.0411
# race_american_indian: 0.0407
# race_other: 0.0069
# County_Other: 0.2120
# County_anderson: 0.0149
# County_bell: 0.0036
# County_blount: -0.1617
# County_bradley: 0.0082
# County_campbell: -0.0181
# County_carter: -0.2432
# County_claiborn: 0.0282
# County_cocke: -0.1834
# County_cumberland: -0.3814
# County_fentress: -0.0222
# County_grainger: 0.0155
# County_greene: 0.0270
# County_hamblen: 0.0286
# County_hamilton: 0.0015
# County_hancock: 0.0032
# County_harlan: -0.1970
# County_hawkins: -0.0764
# County_jefferson: 0.0124
# County_knox: 0.1765
# County_lee: -0.0970
# County_loudon: -0.1450
# County_mcminn: -0.0832
# County_meigs: 0.0270
# County_monroe: -0.0173
# County_morgan: 0.0317
# County_outofstate: -0.2656
# County_overton: -0.0292
# County_polk: -0.0207
# County_putnam: -0.0000
# County_rhea: 0.0715
# County_roane: -0.0646
# County_scott: 0.0371
# County_sevier: -0.1815
# County_sullivan: -0.1687
# County_union: 0.0327
# County_unknown: 0.2055
# County_washburn: 0.0174
# County_washington: -0.1033
# Episiotomy_LT_Medio: 0.0010
# Episiotomy_Midline: -0.0083
# Episiotomy_None: -0.1360
# Episiotomy_RT_Medio: 0.1959
# Laceration.Extension_First: -0.4687
# Laceration.Extension_Fourth: -0.0483
# Laceration.Extension_NAnone: 0.6914
# Laceration.Extension_Second: -0.4876
# Laceration.Extension_Third: -0.1715
# Laceration.Extension_unknown: 0.4667
# Amniotic.Fluid.Color_NAnone: 0.0000
# Amniotic.Fluid.Color_PartMec: -0.2875
# Amniotic.Fluid.Color_bloody: 0.0611
# Amniotic.Fluid.Color_brown: 0.0000
# Amniotic.Fluid.Color_clear: 0.0418
# Amniotic.Fluid.Color_heavy meconium: -0.1083
# Amniotic.Fluid.Color_light meconium: -0.0127
# Amniotic.Fluid.Color_moderate meconium: 0.0000
# Amniotic.Fluid.Color_none: 0.3471
# Attempt.to.Vbac_NAnone: -0.1819
# Attempt.to.Vbac_No: 0.0140
# Attempt.to.Vbac_Yes: 0.2472
# Membranes.Rupture.Method_AROM: 0.0005
# Membranes.Rupture.Method_NAnone: 0.0000
# Membranes.Rupture.Method_N_A: 0.0000
# Membranes.Rupture.Method_SROM: -0.0005
# Oxytocin_Aug: 0.1446
# Oxytocin_Ind: -0.0541
# Oxytocin_NAnone: -0.0962
# Oxytocin_unknown: 0.1712
# Delivery.Month_Apr: -0.0531
# Delivery.Month_Aug: 0.2329
# Delivery.Month_Dec: 0.2078
# Delivery.Month_Feb: -0.1708
# Delivery.Month_Jan: -0.1161
# Delivery.Month_July: -0.2436
# Delivery.Month_June: 0.0104
# Delivery.Month_Mar: 0.0003
# Delivery.Month_May: 0.0530
# Delivery.Month_Nov: -0.0883
# Delivery.Month_Oct: 0.1162
# Delivery.Month_Sept: 0.0460
# Gestational.Status.A_2: -0.0428
# Gestational.Status.A_4: -0.0048
# Gestational.Status.A_Postterm: -0.1604
# Gestational.Status.A_Preterm: -0.0250
# Gestational.Status.A_Term: 0.0735
# Gestational.Status.A_unknown: 0.0000
# Born.In.Route.A_No: 0.1907
# Born.In.Route.A_Yes: -0.1907
# Fetal.Presentation.A_Breech: 0.2428
# Fetal.Presentation.A_Cephalic: -0.1528
# Fetal.Presentation.A_Compound: -0.2338
# Fetal.Presentation.A_NAnone: -0.2429
# Fetal.Presentation.A_NAnone, unsure, baby in mother's hands as RN entered room: -0.0399
# Fetal.Presentation.A_Oblique: 0.0000
# Fetal.Presentation.A_Transver: 0.1840
# Fetal.Presentation.A_UnAssess: 0.1333
# Forceps.a_Breech: -0.1432
# Forceps.a_Cesarean: -0.1184
# Forceps.a_Failed: 0.1122
# Forceps.a_Low: -0.1633
# Forceps.a_Mid: -0.0345
# Forceps.a_NAnone: 0.2439
# Forceps.a_Outlet: -0.1551
# Vacuum.Extraction.A_Cesarean: 0.0485
# Vacuum.Extraction.A_Failed: 0.0312
# Vacuum.Extraction.A_NAnone: 0.0076
# Vacuum.Extraction.A_Success: -0.0406
# VBAC.A_Failed: 0.3865
# VBAC.A_NAnone: 0.3446
# VBAC.A_Success: -0.5791
# Infant.Sex.A_F: -0.0850
# Infant.Sex.A_M: 0.0850
# Cervical.Ripening.Agents_Cervidil: -0.0425
# Cervical.Ripening.Agents_FoleyBal: -0.0209
# Cervical.Ripening.Agents_Laminari: -0.0277
# Cervical.Ripening.Agents_Misopros: 0.1446
# Cervical.Ripening.Agents_NAnone: -0.0503
# Cervical.Ripening.Agents_Other: 0.0139
# Cervical.Ripening.Agents_Prepidil: -0.1087
# Preterm.Labor_No: -0.0138
# Preterm.Labor_Yes: 0.0138
# Premature.Rom_No: -0.0162
# Premature.Rom_Yes: 0.0162
# Hypertensive.Disorders.Preg_No: 0.1746
# Hypertensive.Disorders.Preg_Yes: -0.1746
# Diabetes_No: 0.0462
# Diabetes_Yes: -0.0462
# Adm.Alcohol_No: 0.0077
# Adm.Alcohol_YES: -0.0077
# Adm.Cigarettes_daily: 0.0770
# Adm.Cigarettes_former: -0.0124
# Adm.Cigarettes_heavy: 0.0005
# Adm.Cigarettes_light: -0.2061
# Adm.Cigarettes_never: -0.0294
# Adm.Cigarettes_vape: -0.0711
# Adm.Marijuana_No: -0.0127
# Adm.Marijuana_YES: 0.0127
# Adm.Cocaine.Crack_No: 0.0758
# Adm.Cocaine.Crack_YES: -0.0758
# Adm.Illicit.Drugs_No: 0.0978
# Adm.Illicit.Drugs_YES: -0.0978
# Provider.On.Admission_Barry: -0.2448
# Provider.On.Admission_Brabson: 0.0039
# Provider.On.Admission_ETROBGYN: -0.4389
# Provider.On.Admission_Fields: -0.4226
# Provider.On.Admission_HS: 0.0759
# Provider.On.Admission_HS/SUD: -0.1399
# Provider.On.Admission_HS/UFP: -0.0310
# Provider.On.Admission_HSHR: 0.0658
# Provider.On.Admission_HSHR/SAC: 0.0610
# Provider.On.Admission_Murphy: -0.0183
# Provider.On.Admission_Other: -0.1186
# Provider.On.Admission_Perry: 0.0711
# Provider.On.Admission_ROC: -0.0604
# Provider.On.Admission_ROC/WCG: -0.0042
# Provider.On.Admission_ROC/WSC: -0.0612
# Provider.On.Admission_ROCK: 0.0931
# Provider.On.Admission_ROC_(BC): -0.0668
# Provider.On.Admission_RR: 0.0531
# Provider.On.Admission_SMBMC: -0.2384
# Provider.On.Admission_Schoutko: -0.0359
# Provider.On.Admission_Shirk: 0.0000
# Provider.On.Admission_UFP: -0.0581
# Provider.On.Admission_UM: -0.2207
# Provider.On.Admission_UTGYN/OB: -0.1364
# Provider.On.Admission_UTH: -0.0226
# Provider.On.Admission_UWS: 0.1397
# Provider.On.Admission_UWS/ROC: -0.0063
# Provider.On.Admission_WCG: 0.1233
# Provider.On.Admission_WCG/SUD: -0.0049
# Provider.On.Admission_unknown: -0.0440
# Ethnicity_D: 0.0042
# Ethnicity_H: -0.0266
# Ethnicity_O: 0.0083
# Ethnicity_U: 0.0666
#
# Class 1 coefficients:
# Age: -0.4668
# Gravida: 0.1565
# Para: 0.9044
# Number.of.Babies.In.Womb: -0.1703
# Delivery.Year: 0.0453
# Infant.Cord.Vessels.A: 0.0171
# Infant.Length.A: -0.2166
# Birthweight.A: 0.1892
# GA.At.Birth.A: -0.6484
# Weight.Prepregnancy: -0.0877
# Weight.Gain.Pounds: 0.0007
# OFC.At.Birth.Baby.A.In: -0.0978
# Quantitative.Blood.Loss.DS: -0.9062
# Weight.Delivery: -0.0897
# BMI_delivery: -0.2438
# BMI_prepregnancy: 0.1573
# Labortime: -0.6639
# delivery_anesthesia_epidural: -0.7490
# delivery_anesthesia_spinal: -1.6675
# delivery_anesthesia_local: 0.8212
# delivery_anesthesia_pudenal: 0.4961
# delivery_anesthesia_cse: -0.2967
# delivery_anesthesia_general: -2.0579
# delivery_anesthesia_intrathe: 0.5240
# labor_anesthesia_epidural: 0.1608
# labor_anesthesia_spinal: 0.1525
# labor_anesthesia_cse: 0.0970
# labor_anesthesia_general: -0.0353
# labor_anesthesia_iv_sedation: -0.1184
# laceration_type_none: -2.2880
# laceration_type_vaginal: -0.4927
# laceration_type_perineal: 0.2725
# laceration_type_periuret: 0.3178
# laceration_type_cervical: 0.0276
# laceration_type_other: 0.5715
# infant_complications_A_brady: -0.3638
# infant_complications_A_acidosis: 0.1853
# infant_complications_A_meconium: 0.0021
# infant_complications_A_cord_pro: -0.2111
# infant_complications_A_MLD: -0.5638
# infant_complications_A_MVD: 0.0188
# infant_complications_A_oligohyd: 0.2106
# infant_complications_A_shol_dys: 0.9806
# infant_complications_A_polyhydr: 0.0658
# infant_complications_A_decvarib: -0.0860
# infant_complications_A_tachy: -0.2718
# infant_complications_A_other: -0.2095
# reason_for_admission_Spon_Ab: 0.7027
# reason_for_admission_Labor: 0.0340
# reason_for_admission_PTL: 0.1339
# reason_for_admission_Induce: -0.1363
# reason_for_admission_Rept_CS: -0.2207
# reason_for_admission_Prim_CS: -0.3844
# reason_for_admission_ROM: -0.1611
# reason_for_admission_Observe: -0.2419
# reason_for_admission_other: -0.1450
# race_black: 0.0383
# race_white: 0.0223
# race_pacific_islander: 0.0352
# race_asian: 0.0265
# race_arabic: 0.0161
# race_american_indian: 0.0158
# race_other: -0.1130
# County_Other: 0.0488
# County_anderson: 0.0118
# County_bell: 0.0027
# County_blount: -0.0132
# County_bradley: 0.0351
# County_campbell: 0.1142
# County_carter: 0.1151
# County_claiborn: -0.0937
# County_cocke: 0.0860
# County_cumberland: 0.2474
# County_fentress: -0.0054
# County_grainger: 0.0244
# County_greene: -0.0665
# County_hamblen: -0.0269
# County_hamilton: -0.0141
# County_hancock: 0.0488
# County_harlan: 0.1073
# County_hawkins: 0.0687
# County_jefferson: 0.0161
# County_knox: -0.1498
# County_lee: 0.0348
# County_loudon: 0.1182
# County_mcminn: 0.0810
# County_meigs: 0.0087
# County_monroe: 0.0153
# County_morgan: 0.0267
# County_outofstate: 0.1295
# County_overton: -0.0511
# County_polk: -0.0245
# County_putnam: -0.0081
# County_rhea: -0.0471
# County_roane: 0.0998
# County_scott: -0.0106
# County_sevier: 0.0854
# County_sullivan: 0.1491
# County_union: -0.0082
# County_unknown: -0.0892
# County_washburn: -0.0352
# County_washington: 0.0451
# Episiotomy_LT_Medio: 0.0520
# Episiotomy_Midline: 0.2778
# Episiotomy_None: -0.4720
# Episiotomy_RT_Medio: 0.3805
# Laceration.Extension_First: 0.0906
# Laceration.Extension_Fourth: 0.1148
# Laceration.Extension_NAnone: -0.9909
# Laceration.Extension_Second: 1.0579
# Laceration.Extension_Third: 0.5190
# Laceration.Extension_unknown: -0.5427
# Amniotic.Fluid.Color_NAnone: 0.0000
# Amniotic.Fluid.Color_PartMec: 0.1152
# Amniotic.Fluid.Color_bloody: -0.0456
# Amniotic.Fluid.Color_brown: 0.0000
# Amniotic.Fluid.Color_clear: -0.0289
# Amniotic.Fluid.Color_heavy meconium: 0.1162
# Amniotic.Fluid.Color_light meconium: -0.0068
# Amniotic.Fluid.Color_moderate meconium: 0.0000
# Amniotic.Fluid.Color_none: -0.0608
# Attempt.to.Vbac_NAnone: 0.0587
# Attempt.to.Vbac_No: -0.1414
# Attempt.to.Vbac_Yes: 0.0714
# Membranes.Rupture.Method_AROM: -0.0525
# Membranes.Rupture.Method_NAnone: 0.0000
# Membranes.Rupture.Method_N_A: 0.0000
# Membranes.Rupture.Method_SROM: 0.0525
# Oxytocin_Aug: -0.0160
# Oxytocin_Ind: 0.0245
# Oxytocin_NAnone: 0.0385
# Oxytocin_unknown: -0.1767
# Delivery.Month_Apr: 0.0209
# Delivery.Month_Aug: -0.1884
# Delivery.Month_Dec: -0.1171
# Delivery.Month_Feb: 0.0719
# Delivery.Month_Jan: 0.0664
# Delivery.Month_July: 0.1067
# Delivery.Month_June: 0.0051
# Delivery.Month_Mar: -0.0348
# Delivery.Month_May: -0.0258
# Delivery.Month_Nov: 0.0589
# Delivery.Month_Oct: -0.0121
# Delivery.Month_Sept: 0.0504
# Gestational.Status.A_2: -0.0562
# Gestational.Status.A_4: 0.0156
# Gestational.Status.A_Postterm: 0.1169
# Gestational.Status.A_Preterm: -0.0499
# Gestational.Status.A_Term: 0.0142
# Gestational.Status.A_unknown: 0.0000
# Born.In.Route.A_No: -0.0978
# Born.In.Route.A_Yes: 0.0978
# Fetal.Presentation.A_Breech: -0.3181
# Fetal.Presentation.A_Cephalic: 0.2757
# Fetal.Presentation.A_Compound: 0.1151
# Fetal.Presentation.A_NAnone: 0.2252
# Fetal.Presentation.A_NAnone, unsure, baby in mother's hands as RN entered room: 0.0342
# Fetal.Presentation.A_Oblique: 0.0000
# Fetal.Presentation.A_Transver: -0.2888
# Fetal.Presentation.A_UnAssess: -0.0632
# Forceps.a_Breech: 0.0468
# Forceps.a_Cesarean: -0.0031
# Forceps.a_Failed: -0.2184
# Forceps.a_Low: 0.4411
# Forceps.a_Mid: 0.0507
# Forceps.a_NAnone: -0.4152
# Forceps.a_Outlet: 0.2187
# Vacuum.Extraction.A_Cesarean: -0.1478
# Vacuum.Extraction.A_Failed: 0.0162
# Vacuum.Extraction.A_NAnone: 0.0056
# Vacuum.Extraction.A_Success: 0.0643
# VBAC.A_Failed: -0.7670
# VBAC.A_NAnone: -0.1130
# VBAC.A_Success: 0.5144
# Infant.Sex.A_F: 0.0552
# Infant.Sex.A_M: -0.0552
# Cervical.Ripening.Agents_Cervidil: -0.0071
# Cervical.Ripening.Agents_FoleyBal: -0.0425
# Cervical.Ripening.Agents_Laminari: 0.0161
# Cervical.Ripening.Agents_Misopros: -0.1804
# Cervical.Ripening.Agents_NAnone: 0.1757
# Cervical.Ripening.Agents_Other: -0.0922
# Cervical.Ripening.Agents_Prepidil: -0.0510
# Preterm.Labor_No: 0.0361
# Preterm.Labor_Yes: -0.0361
# Premature.Rom_No: 0.0058
# Premature.Rom_Yes: -0.0058
# Hypertensive.Disorders.Preg_No: 0.0110
# Hypertensive.Disorders.Preg_Yes: -0.0110
# Diabetes_No: -0.0120
# Diabetes_Yes: 0.0120
# Adm.Alcohol_No: -0.0121
# Adm.Alcohol_YES: 0.0121
# Adm.Cigarettes_daily: -0.0494
# Adm.Cigarettes_former: 0.0134
# Adm.Cigarettes_heavy: 0.0135
# Adm.Cigarettes_light: 0.0788
# Adm.Cigarettes_never: 0.0206
# Adm.Cigarettes_vape: 0.0037
# Adm.Marijuana_No: 0.0371
# Adm.Marijuana_YES: -0.0371
# Adm.Cocaine.Crack_No: -0.0330
# Adm.Cocaine.Crack_YES: 0.0330
# Adm.Illicit.Drugs_No: -0.0765
# Adm.Illicit.Drugs_YES: 0.0765
# Provider.On.Admission_Barry: 0.1805
# Provider.On.Admission_Brabson: -0.0159
# Provider.On.Admission_ETROBGYN: 0.3123
# Provider.On.Admission_Fields: 0.1733
# Provider.On.Admission_HS: 0.0260
# Provider.On.Admission_HS/SUD: 0.0585
# Provider.On.Admission_HS/UFP: -0.0532
# Provider.On.Admission_HSHR: -0.0925
# Provider.On.Admission_HSHR/SAC: -0.0389
# Provider.On.Admission_Murphy: -0.0501
# Provider.On.Admission_Other: 0.0727
# Provider.On.Admission_Perry: -0.0940
# Provider.On.Admission_ROC: -0.0702
# Provider.On.Admission_ROC/WCG: 0.0472
# Provider.On.Admission_ROC/WSC: -0.0498
# Provider.On.Admission_ROCK: -0.0671
# Provider.On.Admission_ROC_(BC): 0.0194
# Provider.On.Admission_RR: 0.0184
# Provider.On.Admission_SMBMC: 0.1839
# Provider.On.Admission_Schoutko: 0.0451
# Provider.On.Admission_Shirk: 0.0000
# Provider.On.Admission_UFP: 0.0957
# Provider.On.Admission_UM: 0.2562
# Provider.On.Admission_UTGYN/OB: 0.0710
# Provider.On.Admission_UTH: 0.0266
# Provider.On.Admission_UWS: -0.0849
# Provider.On.Admission_UWS/ROC: -0.0003
# Provider.On.Admission_WCG: -0.2014
# Provider.On.Admission_WCG/SUD: 0.0495
# Provider.On.Admission_unknown: 0.0332
# Ethnicity_D: 0.0164
# Ethnicity_H: -0.0199
# Ethnicity_O: 0.0154
# Ethnicity_U: -0.0072
#
# Class 2 coefficients:
# Age: 0.1573
# Gravida: 0.2664
# Para: -0.7898
# Number.of.Babies.In.Womb: 0.1227
# Delivery.Year: -0.0321
# Infant.Cord.Vessels.A: 0.1387
# Infant.Length.A: 0.2469
# Birthweight.A: 0.0951
# GA.At.Birth.A: 0.3354
# Weight.Prepregnancy: 0.6421
# Weight.Gain.Pounds: 0.0855
# OFC.At.Birth.Baby.A.In: 0.1488
# Quantitative.Blood.Loss.DS: 0.5439
# Weight.Delivery: -0.5457
# BMI_delivery: 0.3128
# BMI_prepregnancy: -0.3727
# Labortime: 0.5256
# delivery_anesthesia_epidural: 0.4655
# delivery_anesthesia_spinal: 1.0106
# delivery_anesthesia_local: 0.0696
# delivery_anesthesia_pudenal: -0.3570
# delivery_anesthesia_cse: 0.2080
# delivery_anesthesia_general: 0.7171
# delivery_anesthesia_intrathe: -0.3691
# labor_anesthesia_epidural: 0.0149
# labor_anesthesia_spinal: 0.4002
# labor_anesthesia_cse: 0.1686
# labor_anesthesia_general: -0.5924
# labor_anesthesia_iv_sedation: -0.0437
# laceration_type_none: 1.7508
# laceration_type_vaginal: -0.0679
# laceration_type_perineal: -1.3480
# laceration_type_periuret: 0.0655
# laceration_type_cervical: 0.0506
# laceration_type_other: 0.7331
# infant_complications_A_brady: -0.2992
# infant_complications_A_acidosis: 0.0735
# infant_complications_A_meconium: 0.0065
# infant_complications_A_cord_pro: -0.5391
# infant_complications_A_MLD: 0.0294
# infant_complications_A_MVD: -0.2461
# infant_complications_A_oligohyd: 0.1571
# infant_complications_A_shol_dys: 0.5718
# infant_complications_A_polyhydr: 0.0679
# infant_complications_A_decvarib: 0.1152
# infant_complications_A_tachy: 0.1051
# infant_complications_A_other: -0.2067
# reason_for_admission_Spon_Ab: 0.1673
# reason_for_admission_Labor: -0.1634
# reason_for_admission_PTL: -0.0442
# reason_for_admission_Induce: -0.2881
# reason_for_admission_Rept_CS: 0.0231
# reason_for_admission_Prim_CS: 0.0650
# reason_for_admission_ROM: 0.0538
# reason_for_admission_Observe: 0.0699
# reason_for_admission_other: -0.1410
# race_black: -0.2068
# race_white: -0.0771
# race_pacific_islander: 0.0254
# race_asian: 0.0916
# race_arabic: -0.0573
# race_american_indian: -0.0565
# race_other: 0.1061
# County_Other: -0.2608
# County_anderson: -0.0267
# County_bell: -0.0062
# County_blount: 0.1749
# County_bradley: -0.0433
# County_campbell: -0.0961
# County_carter: 0.1281
# County_claiborn: 0.0655
# County_cocke: 0.0974
# County_cumberland: 0.1340
# County_fentress: 0.0276
# County_grainger: -0.0399
# County_greene: 0.0395
# County_hamblen: -0.0017
# County_hamilton: 0.0126
# County_hancock: -0.0521
# County_harlan: 0.0897
# County_hawkins: 0.0077
# County_jefferson: -0.0285
# County_knox: -0.0267
# County_lee: 0.0622
# County_loudon: 0.0268
# County_mcminn: 0.0023
# County_meigs: -0.0356
# County_monroe: 0.0020
# County_morgan: -0.0584
# County_outofstate: 0.1361
# County_overton: 0.0804
# County_polk: 0.0452
# County_putnam: 0.0081
# County_rhea: -0.0245
# County_roane: -0.0352
# County_scott: -0.0266
# County_sevier: 0.0961
# County_sullivan: 0.0196
# County_union: -0.0245
# County_unknown: -0.1163
# County_washburn: 0.0177
# County_washington: 0.0583
# Episiotomy_LT_Medio: -0.0530
# Episiotomy_Midline: -0.2695
# Episiotomy_None: 0.6079
# Episiotomy_RT_Medio: -0.5764
# Laceration.Extension_First: 0.3781
# Laceration.Extension_Fourth: -0.0665
# Laceration.Extension_NAnone: 0.2995
# Laceration.Extension_Second: -0.5703
# Laceration.Extension_Third: -0.3475
# Laceration.Extension_unknown: 0.0760
# Amniotic.Fluid.Color_NAnone: 0.0000
# Amniotic.Fluid.Color_PartMec: 0.1723
# Amniotic.Fluid.Color_bloody: -0.0156
# Amniotic.Fluid.Color_brown: 0.0000
# Amniotic.Fluid.Color_clear: -0.0129
# Amniotic.Fluid.Color_heavy meconium: -0.0079
# Amniotic.Fluid.Color_light meconium: 0.0195
# Amniotic.Fluid.Color_moderate meconium: 0.0000
# Amniotic.Fluid.Color_none: -0.2862
# Attempt.to.Vbac_NAnone: 0.1232
# Attempt.to.Vbac_No: 0.1274
# Attempt.to.Vbac_Yes: -0.3186
# Membranes.Rupture.Method_AROM: 0.0521
# Membranes.Rupture.Method_NAnone: 0.0000
# Membranes.Rupture.Method_N_A: 0.0000
# Membranes.Rupture.Method_SROM: -0.0521
# Oxytocin_Aug: -0.1285
# Oxytocin_Ind: 0.0296
# Oxytocin_NAnone: 0.0577
# Oxytocin_unknown: 0.0055
# Delivery.Month_Apr: 0.0322
# Delivery.Month_Aug: -0.0445
# Delivery.Month_Dec: -0.0906
# Delivery.Month_Feb: 0.0990
# Delivery.Month_Jan: 0.0497
# Delivery.Month_July: 0.1369
# Delivery.Month_June: -0.0155
# Delivery.Month_Mar: 0.0345
# Delivery.Month_May: -0.0272
# Delivery.Month_Nov: 0.0293
# Delivery.Month_Oct: -0.1041
# Delivery.Month_Sept: -0.0964
# Gestational.Status.A_2: 0.0990
# Gestational.Status.A_4: -0.0108
# Gestational.Status.A_Postterm: 0.0435
# Gestational.Status.A_Preterm: 0.0748
# Gestational.Status.A_Term: -0.0878
# Gestational.Status.A_unknown: 0.0000
# Born.In.Route.A_No: -0.0929
# Born.In.Route.A_Yes: 0.0929
# Fetal.Presentation.A_Breech: 0.0753
# Fetal.Presentation.A_Cephalic: -0.1228
# Fetal.Presentation.A_Compound: 0.1188
# Fetal.Presentation.A_NAnone: 0.0177
# Fetal.Presentation.A_NAnone, unsure, baby in mother's hands as RN entered room: 0.0056
# Fetal.Presentation.A_Oblique: 0.0000
# Fetal.Presentation.A_Transver: 0.1047
# Fetal.Presentation.A_UnAssess: -0.0701
# Forceps.a_Breech: 0.0965
# Forceps.a_Cesarean: 0.1215
# Forceps.a_Failed: 0.1062
# Forceps.a_Low: -0.2778
# Forceps.a_Mid: -0.0162
# Forceps.a_NAnone: 0.1713
# Forceps.a_Outlet: -0.0636
# Vacuum.Extraction.A_Cesarean: 0.0993
# Vacuum.Extraction.A_Failed: -0.0474
# Vacuum.Extraction.A_NAnone: -0.0133
# Vacuum.Extraction.A_Success: -0.0238
# VBAC.A_Failed: 0.3805
# VBAC.A_NAnone: -0.2316
# VBAC.A_Success: 0.0647
# Infant.Sex.A_F: 0.0298
# Infant.Sex.A_M: -0.0298
# Cervical.Ripening.Agents_Cervidil: 0.0496
# Cervical.Ripening.Agents_FoleyBal: 0.0634
# Cervical.Ripening.Agents_Laminari: 0.0116
# Cervical.Ripening.Agents_Misopros: 0.0358
# Cervical.Ripening.Agents_NAnone: -0.1254
# Cervical.Ripening.Agents_Other: 0.0784
# Cervical.Ripening.Agents_Prepidil: 0.1598
# Preterm.Labor_No: -0.0222
# Preterm.Labor_Yes: 0.0222
# Premature.Rom_No: 0.0103
# Premature.Rom_Yes: -0.0103
# Hypertensive.Disorders.Preg_No: -0.1856
# Hypertensive.Disorders.Preg_Yes: 0.1856
# Diabetes_No: -0.0342
# Diabetes_Yes: 0.0342
# Adm.Alcohol_No: 0.0044
# Adm.Alcohol_YES: -0.0044
# Adm.Cigarettes_daily: -0.0275
# Adm.Cigarettes_former: -0.0010
# Adm.Cigarettes_heavy: -0.0140
# Adm.Cigarettes_light: 0.1273
# Adm.Cigarettes_never: 0.0088
# Adm.Cigarettes_vape: 0.0674
# Adm.Marijuana_No: -0.0244
# Adm.Marijuana_YES: 0.0244
# Adm.Cocaine.Crack_No: -0.0428
# Adm.Cocaine.Crack_YES: 0.0428
# Adm.Illicit.Drugs_No: -0.0213
# Adm.Illicit.Drugs_YES: 0.0213
# Provider.On.Admission_Barry: 0.0643
# Provider.On.Admission_Brabson: 0.0121
# Provider.On.Admission_ETROBGYN: 0.1267
# Provider.On.Admission_Fields: 0.2493
# Provider.On.Admission_HS: -0.1019
# Provider.On.Admission_HS/SUD: 0.0814
# Provider.On.Admission_HS/UFP: 0.0841
# Provider.On.Admission_HSHR: 0.0267
# Provider.On.Admission_HSHR/SAC: -0.0222
# Provider.On.Admission_Murphy: 0.0683
# Provider.On.Admission_Other: 0.0460
# Provider.On.Admission_Perry: 0.0229
# Provider.On.Admission_ROC: 0.1306
# Provider.On.Admission_ROC/WCG: -0.0430
# Provider.On.Admission_ROC/WSC: 0.1110
# Provider.On.Admission_ROCK: -0.0261
# Provider.On.Admission_ROC_(BC): 0.0474
# Provider.On.Admission_RR: -0.0715
# Provider.On.Admission_SMBMC: 0.0545
# Provider.On.Admission_Schoutko: -0.0092
# Provider.On.Admission_Shirk: 0.0000
# Provider.On.Admission_UFP: -0.0376
# Provider.On.Admission_UM: -0.0356
# Provider.On.Admission_UTGYN/OB: 0.0654
# Provider.On.Admission_UTH: -0.0041
# Provider.On.Admission_UWS: -0.0548
# Provider.On.Admission_UWS/ROC: 0.0066
# Provider.On.Admission_WCG: 0.0781
# Provider.On.Admission_WCG/SUD: -0.0446
# Provider.On.Admission_unknown: 0.0108
# Ethnicity_D: -0.0206
# Ethnicity_H: 0.0464
# Ethnicity_O: -0.0237
# Ethnicity_U: -0.0594
#
# Intercepts:
# Class 0 intercept: -3.0178
# Class 1 intercept: 5.6547
# Class 2 intercept: -2.6369

# %%
coefficients3.shape
# Out:
# (3, 239)

# %%
len(feature_list)
# Out:
# 239

# %%
coefficients3_imp = pd.DataFrame(coefficients3)
coefficients3_imp
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.309439 -0.422943 -0.114597  0.047669 -0.013202 -0.155835 -0.030341
# 1 -0.466768  0.156501  0.904357 -0.170320  0.045315  0.017091 -0.216585
# 2  0.157329  0.266442 -0.789759  0.122651 -0.032112  0.138744  0.246926
#
#         7         8         9    ...       229       230       231       232  \
# 0 -0.284307  0.313040 -0.554341  ... -0.022572  0.139726 -0.006261  0.123277
# 1  0.189195 -0.648440 -0.087734  ...  0.026640 -0.084876 -0.000316 -0.201392
# 2  0.095113  0.335399  0.642075  ... -0.004068 -0.054850  0.006577  0.078115
#
#         233       234       235       236       237       238
# 0 -0.004879 -0.044002  0.004181 -0.026572  0.008343  0.066580
# 1  0.049524  0.033249  0.016400 -0.019856  0.015387 -0.007209
# 2 -0.044644  0.010754 -0.020581  0.046427 -0.023730 -0.059371
#
# [3 rows x 239 columns]

# %%
coeff_df = pd.DataFrame(coefficients3, columns=X_test.columns)
coeff_df = coeff_df.T

# %%
coeff_df.columns = ['emergency', 'vag', 'non-emergency']
coeff_df['max_col'] = coeff_df.idxmax(axis=1)

# Display the updated dataframe
print(coeff_df)
# Out:
#                                emergency       vag  non-emergency  \
# Age                             0.309439 -0.466768       0.157329
# Gravida                        -0.422943  0.156501       0.266442
# Para                           -0.114597  0.904357      -0.789759
# Number.of.Babies.In.Womb        0.047669 -0.170320       0.122651
# Delivery.Year                  -0.013202  0.045315      -0.032112
# ...                                  ...       ...            ...
# Provider.On.Admission_unknown  -0.044002  0.033249       0.010754
# Ethnicity_D                     0.004181  0.016400      -0.020581
# Ethnicity_H                    -0.026572 -0.019856       0.046427
# Ethnicity_O                     0.008343  0.015387      -0.023730
# Ethnicity_U                     0.066580 -0.007209      -0.059371
#
#                                      max_col
# Age                                emergency
# Gravida                        non-emergency
# Para                                     vag
# Number.of.Babies.In.Womb       non-emergency
# Delivery.Year                            vag
# ...                                      ...
# Provider.On.Admission_unknown            vag
# Ethnicity_D                              vag
# Ethnicity_H                    non-emergency
# Ethnicity_O                              vag
# Ethnicity_U                        emergency
#
# [239 rows x 4 columns]

# %%
coeff_df.to_csv('../data/coef_df_ml_mlr.csv')

# %% [markdown]
# ### data: mice

# %%
X_train, X_test, y_train, y_test = helpers.split_and_scale_data(features_mice, labels_mice)

# %%
y_train.value_counts()

# %%
y_test.value_counts()

# %%
X_train, y_train = helpers.perform_SMOTE(X_train, y_train)
y_train.value_counts()

# %% [markdown]
# ####  complete
